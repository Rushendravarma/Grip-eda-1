# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
import os
print(os.getcwd())
# inorder to change directory for direct upload
#os.chdir("C:\Users\m.Rushendra varma\Downloads")
# Out:
# C:\Users\m.Rushendra varma

# %%
rishi=pd.read_csv('SampleSuperstore.csv')
rishi
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
rishi.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
v1 = sns.barplot(x="Region",y="Profit",data=rishi,hue="Segment")
v1
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Profit'>

# %%
v2=sns.barplot(x="Segment",y="Profit",data=rishi,hue="Region")

# %%
v3=sns.barplot(x="Segment",y="Sales",data=rishi,hue="Region")
v3
# Out:
# <AxesSubplot:xlabel='Segment', ylabel='Sales'>

# %%
v4=sns.barplot(x="Region",y="Sales",data=rishi,hue="Ship Mode")
v4
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Sales'>

# %%
v5=sns.barplot(x="Region",y="Sales",data=rishi,hue="Segment")
v5
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Sales'>

# %%
v6=sns.barplot(x="Segment",y="Sales",data=rishi,hue="Ship Mode")
v6
# Out:
# <AxesSubplot:xlabel='Segment', ylabel='Sales'>

# %%
v7=sns.barplot(x="Ship Mode",y="Sales",data=rishi,hue="Segment")
v7
# Out:
# <AxesSubplot:xlabel='Ship Mode', ylabel='Sales'>

# %%
v8=sns.barplot(x='Region',y='Profit',data=rishi,hue='Ship Mode')
v8
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Profit'>

# %%
v9=sns.barplot(x='Segment',y='Profit',data=rishi,hue='Ship Mode')
v9
# Out:
# <AxesSubplot:xlabel='Segment', ylabel='Profit'>

# %% [markdown]
# VIOLIN PLOT B/W STATE and PROFIT with hue as SHIP MODE

# %%
v10=sns.violinplot(x='State',y='Profit',data=rishi,hue='Ship Mode')
v10
# Out:
# <AxesSubplot:xlabel='State', ylabel='Profit'>

# %% [markdown]
# STRIP PLOT

# %%
v11=sns.stripplot(x='State',y='Profit',data=rishi,hue='Ship Mode')
v11
# Out:
# <AxesSubplot:xlabel='State', ylabel='Profit'>

# %% [markdown]
# BOX PLOT

# %%
v12=sns.boxplot(x='State',y='Profit',data=rishi,hue='Ship Mode')
v12
# Out:
# <AxesSubplot:xlabel='State', ylabel='Profit'>

# %% [markdown]
# # FACET HISTORAMS

# %%
g_h = sns.FacetGrid(rishi,row="Region",col="Segment",palette="Set1")
g_h = g_h.map(plt.hist,"Profit")

# %%
g= sns.FacetGrid(rishi,row="Region",col="Segment",hue="Ship Mode",palette="Set1")
kws = dict(s=40,linewidth=0.6,edgecolor="black")
g= g.map(plt.scatter,"Sales","Profit",**kws)

# %%
g= sns.FacetGrid(rishi,row="Region",col="Segment")
kws = dict(s=40,linewidth=0.6,edgecolor="blue")
g= g.map(plt.scatter,"Sales","Profit",**kws)
g.set(xlim=(15,70),ylim=(0,22))

# %%
g= sns.FacetGrid(rishi,row="Region",col="Segment",hue="Ship Mode")
kws = dict(s=40,linewidth=0.6,edgecolor="blue")
g= g.map(plt.scatter,"Sales","Profit",**kws)
g.set(xlim=(15,70),ylim=(0,22))

# %%
g= sns.FacetGrid(rishi,row="Region",col="Segment",hue="Ship Mode",palette="Set1")
kws = dict(s=40,linewidth=0.6,edgecolor="blue")
g= g.map(plt.scatter,"Sales","Profit",**kws)
g.set(xlim=(0,80),ylim=(0,30))
for ax in g.axes.flat:
    ax.plot((0,80),(0,30),c="orange",ls="--")
g.add_legend()

# %%
g= sns.FacetGrid(rishi,row="Region",col="Ship Mode",hue="Segment",palette="Set1")
kws = dict(s=40,linewidth=0.6,edgecolor="blue")
g= g.map(plt.scatter,"Sales","Profit",**kws)
g.set(xlim=(0,80),ylim=(0,30))
for ax in g.axes.flat:
    ax.plot((0,80),(0,30),c="orange",ls="--")
g.add_legend()

# %%
sns.barplot(x='City',y='Profit',data=rishi)
# Out:
# <AxesSubplot:xlabel='City', ylabel='Profit'>

# %%
sns.violinplot(x='City',y='Profit',data=rishi)
# Out:
# <AxesSubplot:xlabel='City', ylabel='Profit'>

# %%
sns.boxplot(x='City',y='Profit',data=rishi)
# Out:
# <AxesSubplot:xlabel='City', ylabel='Profit'>

# %%
sns.stripplot(x='City',y='Profit',data=rishi)
# Out:
# <AxesSubplot:xlabel='City', ylabel='Profit'>

# %%
sns.stripplot(x='City',y='Sales',data=rishi)
# Out:
# <AxesSubplot:xlabel='City', ylabel='Sales'>
